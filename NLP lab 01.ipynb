# %%
txt="Already broken"

# %%
print(txt.split())
# Out:
# ['Already', 'broken']

# %%
import nltk

# %%
from nltk.tokenize import sent_tokenize , word_tokenize

# %%
txt="""Dear hustlers 

We hope this email finds you well. We are pleased to inform you that you have been Selected as one of the interns for the upcoming internship program at CodersCave. Congratulations on your selection! We have reviewed your profile and believe that you possess the skills and potential to contribute to our team.

We kindly request your patience during this process as we work diligently to prepare your official offer letter. The offer letter will contain essential details such as the start date, duration, and any specific requirements or instructions related to your internship position.

Your Internship tenure will start from 1st August, 2023. Further will be shared with offer letter.

Please note that this internship opportunity is unpaid, as it is primarily designed to provide valuable learning experiences and practical exposure in a professional work environment. However, we believe that the knowledge and skills you will gain during your time with us will greatly benefit your future endeavors.

We encourage you to stay connected with us through our official communication channels. We will provide regular updates regarding the internship program, including any orientation sessions or preparatory materials that may be necessary to ensure a successful internship experience.

Join our official discord server for instant updates: Discord Internship group and Common group.

Dont forget to join our community: Linkedin"""

# %%
print(sent_tokenize(txt))
# Out:
# ['Dear hustlers \n\nWe hope this email finds you well.', 'We are pleased to inform you that you have been Selected as one of the interns for the upcoming internship program at CodersCave.', 'Congratulations on your selection!', 'We have reviewed your profile and believe that you possess the skills and potential to contribute to our team.', 'We kindly request your patience during this process as we work diligently to prepare your official offer letter.', 'The offer letter will contain essential details such as the start date, duration, and any specific requirements or instructions related to your internship position.', 'Your Internship tenure will start from 1st August, 2023.', 'Further will be shared with offer letter.', 'Please note that this internship opportunity is unpaid, as it is primarily designed to provide valuable learning experiences and practical exposure in a professional work environment.', 'However, we believe that the knowledge and skills you will gain during your tim
# ...

# %%
print(word_tokenize(txt))
# Out:
# ['Dear', 'hustlers', 'We', 'hope', 'this', 'email', 'finds', 'you', 'well', '.', 'We', 'are', 'pleased', 'to', 'inform', 'you', 'that', 'you', 'have', 'been', 'Selected', 'as', 'one', 'of', 'the', 'interns', 'for', 'the', 'upcoming', 'internship', 'program', 'at', 'CodersCave', '.', 'Congratulations', 'on', 'your', 'selection', '!', 'We', 'have', 'reviewed', 'your', 'profile', 'and', 'believe', 'that', 'you', 'possess', 'the', 'skills', 'and', 'potential', 'to', 'contribute', 'to', 'our', 'team', '.', 'We', 'kindly', 'request', 'your', 'patience', 'during', 'this', 'process', 'as', 'we', 'work', 'diligently', 'to', 'prepare', 'your', 'official', 'offer', 'letter', '.', 'The', 'offer', 'letter', 'will', 'contain', 'essential', 'details', 'such', 'as', 'the', 'start', 'date', ',', 'duration', ',', 'and', 'any', 'specific', 'requirements', 'or', 'instructions', 'related', 'to', 'your', 'internship', 'position', '.', 'Your', 'Internship', 'tenure', 'will', 'start', 'from', '1st', 'August
# ...

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import spacy

# %%
spacyobj=spacy.blank('en')

# %%
tokk=spacyobj(txt)

# %%
print(tokk)
# Out:
# Dear hustlers
#
# We hope this email finds you well. We are pleased to inform you that you have been Selected as one of the interns for the upcoming internship program at CodersCave. Congratulations on your selection! We have reviewed your profile and believe that you possess the skills and potential to contribute to our team.
#
# We kindly request your patience during this process as we work diligently to prepare your official offer letter. The offer letter will contain essential details such as the start date, duration, and any specific requirements or instructions related to your internship position.
#
# Your Internship tenure will start from 1st August, 2023. Further will be shared with offer letter.
#
# ...

# %%
for token in tokk:
    print(token)
# Out:
# Dear
# hustlers
#
#
#
# We
# hope
# this
# email
# finds
# you
# well
# .
# We
# are
# pleased
# to
# inform
# you
# that
# you
# have
# been
# Selected
# as
# one
# of
# the
# interns
# for
# the
# upcoming
# internship
# program
# at
# CodersCave
# .
# Congratulations
# on
# your
# selection
# !
# We
# have
# reviewed
# your
# profile
# and
# believe
# that
# you
# possess
# the
# skills
# and
# potential
# to
# contribute
# to
# our
# team
# .
#
#
#
# We
# kindly
# request
# your
# patience
# during
# this
# process
# as
# we
# work
# diligently
# to
# prepare
# your
# official
# offer
# letter
# .
# The
# offer
# letter
# will
# contain
# essential
# details
# such
# as
# the
# start
# date
# ,
# duration
# ,
# and
# any
# specific
# requirements
# or
# instructions
# related
# to
# your
# internship
# position
# .
#
#
#
# Your
# Internship
# tenure
# will
# start
# from
# 1st
# August
# ,
# 2023
# .
# Further
# will
# be
# shared
# with
# offer
# letter
# .
#
#
#
# Please
# ...

# %%
spacyobj=spacy.load("en_core_web_sm")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 spacyobj=spacy.load("en_core_web_sm")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\spacy\__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#      54         disable=disable,
#      55         enable=enable,
#      56         exclude=exclude,
# ...

# %%
nlp = spacy.load("en_core_web_sm")

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc=nlp(txt)

# %%
for i in doc:
    print(i,"|",spacy.explain(i.pos_),"|",i.lemma_)
# Out:
# Dear | adjective | dear
# hustlers | noun | hustler
#
#
#  | space |
#
#
# We | pronoun | we
# hope | verb | hope
# this | determiner | this
# email | noun | email
# finds | verb | find
# you | pronoun | you
# well | adjective | well
# . | punctuation | .
# We | pronoun | we
# are | auxiliary | be
# pleased | adjective | pleased
# to | particle | to
# inform | verb | inform
# you | pronoun | you
# that | subordinating conjunction | that
# you | pronoun | you
# have | auxiliary | have
# been | auxiliary | be
# Selected | verb | select
# as | adposition | as
# one | numeral | one
# of | adposition | of
# the | determiner | the
# interns | noun | intern
# for | adposition | for
# the | determiner | the
# upcoming | adjective | upcoming
# internship | noun | internship
# program | noun | program
# at | adposition | at
# CodersCave | proper noun | CodersCave
# . | punctuation | .
# Congratulations | noun | congratulation
# on | adposition | on
# your | pronoun | your
# ...
